# %% [markdown]
# # DCGAN

# %% [markdown]
# Import library

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from PIL import Image
import argparse
import math
from keras import backend as K
import timeit

# %% [markdown]
# # Generator model

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(1024, input_shape=(100, ), activation='tanh'))
    model.add(Dense(128 * 7 * 7))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((7, 7, 128), input_shape=(7 * 7 * 128,)))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(64, (5, 5), 
                     padding='same',
                     activation='tanh',
                     data_format='channels_last'))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(1, (5, 5), 
                     padding='same', 
                     activation='tanh',
                     data_format='channels_last'))
    return model

# %% [markdown]
# # Descriminator model

# %%
def discriminator_model():
    model = Sequential()
    model.add(Conv2D(64, (5, 5),
                    padding='same',
                    input_shape=(28, 28, 1),
                    activation='tanh',
                    data_format='channels_last'
    ))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (5, 5),
                    activation='tanh',
                    data_format='channels_last'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(1024, activation='tanh'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %% [markdown]
# # Generator and Discriminator

# %%
def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model

# %% [markdown]
# # Combine image

# %%
def combine_images(generated_images):
    generated_images = generated_images.reshape(generated_images.shape[0], 
                                                generated_images.shape[3], 
                                                generated_images.shape[1],
                                                generated_images.shape[2])
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num) / width))
    shape = generated_images.shape[2:]
    image = np.zeros((height * shape[0], width * shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index / width)
        j = index % width
        image[i * shape[0]:(i + 1) * shape[0], j * shape[1]:(j + 1) * shape[1]] = \
            img[0, :, :]
    return image

# %% [markdown]
# # Training

# %%
def train(BATCH_SIZE):
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    img_rows, img_cols = X_train.shape[1], X_train.shape[2]
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    discriminator_on_generator = \
        generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(100):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0] / BATCH_SIZE))
        start = timeit.default_timer()
        for index in range(int(X_train.shape[0] / BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index * BATCH_SIZE:(index + 1) * BATCH_SIZE]
            image_batch = image_batch.reshape(image_batch.shape[0], 
                                              image_batch.shape[2], 
                                              image_batch.shape[3],
                                              image_batch.shape[1])
            generated_images = generator.predict(noise, verbose=0)
            if index % 200 == 0:
                image = combine_images(generated_images)
                image = image * 127.5 + 127.5
                Image.fromarray(image.astype(np.uint8)).save(
                    str(epoch)+"_"+str(index)+".png")
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if index % 10 == 9:
                generator.save_weights('generator', True)
                discriminator.save_weights('discriminator', True)
        stop = timeit.default_timer()
        print('Epoch time calculate {0}'.format(stop - start))

# %% [markdown]
# # Image Generator

# %%
def generate(BATCH_SIZE, nice=False):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer='SGD')
    generator.load_weights('generator')
    if nice:
        discriminator = discriminator_model()
        discriminator.compile(loss='binary_crossentropy', optimizer='SGD')
        discriminator.load_weights('discriminator')
        noise = np.zeros((BATCH_SIZE * 20, 100))
        for i in range(BATCH_SIZE * 20):
            noise[i, :] = np.random.uniform(-1, 1, 100)
        generated_images = generator.predict(noise, verbose=1)
        d_pret = discriminator.predict(generated_images, verbose=1)
        index = np.arrange(0, BATCH_SIZE * 20)
        index.resize((BATCH_SIZE * 20, 1))
        pre_with_index = list(np.append(d_pret, index, axis=1))
        pre_with_index.sort(key=lambda x: x[0], reverse=True)
        nice_images = np.zeros((BATCH_SIZE, 1) +
                              (generated_images.shape[2:]), dtype=np.float32)
        for i in range(int(BATCH_SIZE)):
            idx = int(pre_with_index[i][1])
            nice_images[i, 0, :, :] = generated_images[idx, 0, :, :]
        image = combine_images(nice_images)
    else:
        noise = np.zeros((BATCH_SIZE, 100))
        for i in range(BATCH_SIZE):
            noise[i, :] = np.random.uniform(-1, 1, 100)
        generated_images = generator.predict(noise, verbose=1)
        image = combine_images(generated_images)
    image = image * 127.5 + 127.5
    Image.fromarray(image.astype(np.uint8)).save('geneted_image.png')

# %% [markdown]
# # Training

# %%
train(BATCH_SIZE=100)
# Out:
# Epoch is 0
# Number of batches 600
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 0 d_loss : 0.678023
# batch 0 g_loss : 0.620962
# batch 1 d_loss : 0.667493
# batch 1 g_loss : 0.617225
# batch 2 d_loss : 0.662333
# batch 2 g_loss : 0.615967
# batch 3 d_loss : 0.649278
# batch 3 g_loss : 0.611214
# batch 4 d_loss : 0.628940
# batch 4 g_loss : 0.602555
# batch 5 d_loss : 0.615188
# batch 5 g_loss : 0.599596
# batch 6 d_loss : 0.597353
# batch 6 g_loss : 0.589336
# batch 7 d_loss : 0.580325
# batch 7 g_loss : 0.587567
# batch 8 d_loss : 0.565466
# batch 8 g_loss : 0.582442
# batch 9 d_loss : 0.544886
# batch 9 g_loss : 0.573681
# batch 10 d_loss : 0.529137
# batch 10 g_loss : 0.572061
# batch 11 d_loss : 0.515028
# batch 11 g_loss : 0.567133
# batch 12 d_loss : 0.511801
# batch 12 g_loss : 0.565002
# batch 13 d_loss : 0.502310
# batch 13 g_loss : 0.556129
# batch 14 d_loss : 0.486091
# batch 14 g_loss : 0.556396
# batch 15 d_loss : 0.475228
# batch 15 g_loss : 0.552154
# batch 16 d_loss : 0.466723
# batch 16 g_loss : 0.550734
# batch 17 d_loss : 0.461204
# batch 17 g_loss : 0.551352
# batch 18 d_loss : 0.456804
# batch 18 g_loss : 0.546881
# batch 19 d_loss : 0.459798
# batch 19 g_loss : 0.542381
# batch 20 d_loss : 0.454125
# batch 20 g_loss : 0.546784
# batch 21 d_loss : 0.448921
# batch 21 g_loss : 0.542822
# batch 22 d_loss : 0.449197
# batch 22 g_loss : 0.540771
# batch 23 d_loss : 0.446528
# batch 23 g_loss : 0.542272
# batch 24 d_loss : 0.443073
# batch 24 g_loss : 0.542161
# batch 25 d_loss : 0.449039
# batch 25 g_loss : 0.546601
# batch 26 d_loss : 0.452651
# batch 26 g_loss : 0.535007
# batch 27 d_loss : 0.453612
# batch 27 g_loss : 0.545509
# batch 28 d_loss : 0.455221
# batch 28 g_loss : 0.546494
# batch 29 d_loss : 0.452398
# batch 29 g_loss : 0.534493
# batch 30 d_loss : 0.451067
# batch 30 g_loss : 0.554756
# batch 31 d_loss : 0.454157
# batch 31 g_loss : 0.546717
# batch 32 d_loss : 0.456783
# batch 32 g_loss : 0.548109
# batch 33 d_loss : 0.466870
# batch 33 g_loss : 0.557188
# batch 34 d_loss : 0.467497
# batch 34 g_loss : 0.552871
# batch 35 d_loss : 0.474441
# batch 35 g_loss : 0.548143
# batch 36 d_loss : 0.482902
# batch 36 g_loss : 0.558214
# batch 37 d_loss : 0.482358
# batch 37 g_loss : 0.566858
# batch 38 d_loss : 0.477424
# batch 38 g_loss : 0.565906
# batch 39 d_loss : 0.483572
# batch 39 g_loss : 0.565949
# batch 40 d_loss : 0.483588
# batch 40 g_loss : 0.570233
# batch 41 d_loss : 0.487455
# batch 41 g_loss : 0.575900
# batch 42 d_loss : 0.498144
# batch 42 g_loss : 0.579685
# batch 43 d_loss : 0.490473
# batch 43 g_loss : 0.585637
# batch 44 d_loss : 0.498611
# batch 44 g_loss : 0.596629
# batch 45 d_loss : 0.499002
# batch 45 g_loss : 0.596112
# batch 46 d_loss : 0.504790
# batch 46 g_loss : 0.608447
# batch 47 d_loss : 0.507383
# batch 47 g_loss : 0.602211
# batch 48 d_loss : 0.511169
# batch 48 g_loss : 0.611306
# batch 49 d_loss : 0.496251
# batch 49 g_loss : 0.620499
# batch 50 d_loss : 0.496252
# batch 50 g_loss : 0.630930
# batch 51 d_loss : 0.500523
# batch 51 g_loss : 0.639150
# batch 52 d_loss : 0.495539
# batch 52 g_loss : 0.643228
# batch 53 d_loss : 0.496273
# batch 53 g_loss : 0.649098
# batch 54 d_loss : 0.485985
# batch 54 g_loss : 0.661866
# batch 55 d_loss : 0.486707
# batch 55 g_loss : 0.677113
# batch 56 d_loss : 0.484198
# batch 56 g_loss : 0.680274
# batch 57 d_loss : 0.471387
# batch 57 g_loss : 0.688826
# batch 58 d_loss : 0.469887
# batch 58 g_loss : 0.693506
# batch 59 d_loss : 0.466567
# batch 59 g_loss : 0.711877
# batch 60 d_loss : 0.470556
# batch 60 g_loss : 0.714800
# batch 61 d_loss : 0.458552
# batch 61 g_loss : 0.724170
# batch 62 d_loss : 0.441702
# batch 62 g_loss : 0.737046
# batch 63 d_loss : 0.438746
# batch 63 g_loss : 0.755007
# batch 64 d_loss : 0.442292
# batch 64 g_loss : 0.757634
# batch 65 d_loss : 0.434807
# batch 65 g_loss : 0.769809
# batch 66 d_loss : 0.432956
# batch 66 g_loss : 0.778635
# batch 67 d_loss : 0.428925
# batch 67 g_loss : 0.787884
# batch 68 d_loss : 0.422192
# batch 68 g_loss : 0.798858
# batch 69 d_loss : 0.409833
# batch 69 g_loss : 0.815014
# batch 70 d_loss : 0.415846
# batch 70 g_loss : 0.820447
# batch 71 d_loss : 0.406290
# batch 71 g_loss : 0.836763
# batch 72 d_loss : 0.408014
# batch 72 g_loss : 0.832366
# batch 73 d_loss : 0.412391
# batch 73 g_loss : 0.826247
# batch 74 d_loss : 0.392193
# batch 74 g_loss : 0.840073
# batch 75 d_loss : 0.382407
# batch 75 g_loss : 0.862342
# batch 76 d_loss : 0.375258
# batch 76 g_loss : 0.858842
# batch 77 d_loss : 0.367166
# batch 77 g_loss : 0.865071
# batch 78 d_loss : 0.358895
# batch 78 g_loss : 0.884029
# batch 79 d_loss : 0.346707
# batch 79 g_loss : 0.862446
# batch 80 d_loss : 0.344104
# batch 80 g_loss : 0.887651
# batch 81 d_loss : 0.347696
# batch 81 g_loss : 0.870759
# batch 82 d_loss : 0.343709
# batch 82 g_loss : 0.895934
# batch 83 d_loss : 0.317622
# batch 83 g_loss : 0.897915
# batch 84 d_loss : 0.305040
# batch 84 g_loss : 0.902278
# batch 85 d_loss : 0.296230
# batch 85 g_loss : 0.904891
# batch 86 d_loss : 0.290167
# batch 86 g_loss : 0.914352
# batch 87 d_loss : 0.292221
# batch 87 g_loss : 0.903283
# batch 88 d_loss : 0.296548
# batch 88 g_loss : 0.924314
# batch 89 d_loss : 0.302956
# batch 89 g_loss : 0.925813
# batch 90 d_loss : 0.289792
# batch 90 g_loss : 0.901246
# batch 91 d_loss : 0.304302
# batch 91 g_loss : 0.931611
# batch 92 d_loss : 0.304657
# batch 92 g_loss : 0.911417
# batch 93 d_loss : 0.274257
# batch 93 g_loss : 0.920918
# batch 94 d_loss : 0.292028
# batch 94 g_loss : 0.890233
# batch 95 d_loss : 0.268257
# batch 95 g_loss : 0.894605
# batch 96 d_loss : 0.264413
# batch 96 g_loss : 0.915436
# batch 97 d_loss : 0.255333
# batch 97 g_loss : 0.906430
# batch 98 d_loss : 0.266143
# batch 98 g_loss : 0.884197
# batch 99 d_loss : 0.265328
# batch 99 g_loss : 0.883839
# batch 100 d_loss : 0.237975
# batch 100 g_loss : 0.878736
# batch 101 d_loss : 0.256329
# batch 101 g_loss : 0.877214
# batch 102 d_loss : 0.212847
# batch 102 g_loss : 0.887668
# batch 103 d_loss : 0.240397
# batch 103 g_loss : 0.852452
# batch 104 d_loss : 0.222907
# batch 104 g_loss : 0.854831
# batch 105 d_loss : 0.232819
# batch 105 g_loss : 0.856611
# batch 106 d_loss : 0.252064
# batch 106 g_loss : 0.869746
# batch 107 d_loss : 0.238172
# batch 107 g_loss : 0.839624
# batch 108 d_loss : 0.223807
# batch 108 g_loss : 0.816620
# batch 109 d_loss : 0.227322
# batch 109 g_loss : 0.809169
# batch 110 d_loss : 0.227637
# batch 110 g_loss : 0.836089
# batch 111 d_loss : 0.224014
# batch 111 g_loss : 0.820511
# batch 112 d_loss : 0.247449
# batch 112 g_loss : 0.804509
# batch 113 d_loss : 0.232104
# batch 113 g_loss : 0.797899
# batch 114 d_loss : 0.237213
# batch 114 g_loss : 0.800108
# batch 115 d_loss : 0.256179
# batch 115 g_loss : 0.798671
# batch 116 d_loss : 0.242434
# batch 116 g_loss : 0.763200
# batch 117 d_loss : 0.234425
# batch 117 g_loss : 0.755709
# batch 118 d_loss : 0.239391
# batch 118 g_loss : 0.763074
# batch 119 d_loss : 0.242014
# batch 119 g_loss : 0.736963
# batch 120 d_loss : 0.247204
# batch 120 g_loss : 0.712144
# batch 121 d_loss : 0.257538
# batch 121 g_loss : 0.698528
# batch 122 d_loss : 0.238978
# batch 122 g_loss : 0.727113
# batch 123 d_loss : 0.274804
# batch 123 g_loss : 0.717242
# batch 124 d_loss : 0.261769
# batch 124 g_loss : 0.701611
# batch 125 d_loss : 0.266319
# batch 125 g_loss : 0.706834
# batch 126 d_loss : 0.270444
# batch 126 g_loss : 0.676858
# batch 127 d_loss : 0.311188
# batch 127 g_loss : 0.714511
# batch 128 d_loss : 0.304783
# batch 128 g_loss : 0.689578
# batch 129 d_loss : 0.259642
# batch 129 g_loss : 0.697798
# batch 130 d_loss : 0.261362
# batch 130 g_loss : 0.687113
# batch 131 d_loss : 0.274762
# batch 131 g_loss : 0.686019
# batch 132 d_loss : 0.298818
# batch 132 g_loss : 0.698338
# batch 133 d_loss : 0.289906
# batch 133 g_loss : 0.690177
# batch 134 d_loss : 0.267677
# batch 134 g_loss : 0.697967
# batch 135 d_loss : 0.280055
# batch 135 g_loss : 0.705427
# batch 136 d_loss : 0.324380
# batch 136 g_loss : 0.682826
# batch 137 d_loss : 0.335583
# batch 137 g_loss : 0.688235
# batch 138 d_loss : 0.321295
# batch 138 g_loss : 0.708288
# batch 139 d_loss : 0.321668
# batch 139 g_loss : 0.703188
# batch 140 d_loss : 0.308934
# batch 140 g_loss : 0.729585
# batch 141 d_loss : 0.289346
# batch 141 g_loss : 0.738226
# batch 142 d_loss : 0.282281
# batch 142 g_loss : 0.755019
# batch 143 d_loss : 0.290294
# batch 143 g_loss : 0.769063
# batch 144 d_loss : 0.307935
# batch 144 g_loss : 0.783177
# batch 145 d_loss : 0.311508
# batch 145 g_loss : 0.797900
# batch 146 d_loss : 0.293465
# batch 146 g_loss : 0.829446
# batch 147 d_loss : 0.293555
# batch 147 g_loss : 0.875253
# batch 148 d_loss : 0.286873
# batch 148 g_loss : 0.891013
# batch 149 d_loss : 0.267527
# batch 149 g_loss : 0.901970
# batch 150 d_loss : 0.254205
# batch 150 g_loss : 0.958360
# batch 151 d_loss : 0.273919
# batch 151 g_loss : 0.985202
# batch 152 d_loss : 0.252804
# batch 152 g_loss : 1.003768
# batch 153 d_loss : 0.246475
# batch 153 g_loss : 1.070273
# batch 154 d_loss : 0.257525
# batch 154 g_loss : 1.135477
# batch 155 d_loss : 0.250439
# batch 155 g_loss : 1.128028
# batch 156 d_loss : 0.226595
# batch 156 g_loss : 1.162930
# batch 157 d_loss : 0.219421
# batch 157 g_loss : 1.235137
# batch 158 d_loss : 0.211213
# batch 158 g_loss : 1.275650
# batch 159 d_loss : 0.201294
# batch 159 g_loss : 1.295279
# batch 160 d_loss : 0.184199
# batch 160 g_loss : 1.299959
# batch 161 d_loss : 0.186177
# batch 161 g_loss : 1.383102
# batch 162 d_loss : 0.177423
# batch 162 g_loss : 1.394972
# batch 163 d_loss : 0.182041
# batch 163 g_loss : 1.475083
# batch 164 d_loss : 0.179217
# batch 164 g_loss : 1.529371
# batch 165 d_loss : 0.179137
# batch 165 g_loss : 1.531397
# batch 166 d_loss : 0.177038
# batch 166 g_loss : 1.563636
# batch 167 d_loss : 0.167312
# batch 167 g_loss : 1.608503
# batch 168 d_loss : 0.175329
# batch 168 g_loss : 1.620161
# batch 169 d_loss : 0.167185
# batch 169 g_loss : 1.653238
# batch 170 d_loss : 0.169473
# batch 170 g_loss : 1.723386
# batch 171 d_loss : 0.167363
# batch 171 g_loss : 1.699936
# batch 172 d_loss : 0.165623
# batch 172 g_loss : 1.722742
# batch 173 d_loss : 0.171233
# batch 173 g_loss : 1.728516
# batch 174 d_loss : 0.174994
# batch 174 g_loss : 1.737515
# batch 175 d_loss : 0.184174
# batch 175 g_loss : 1.798906
# batch 176 d_loss : 0.189856
# batch 176 g_loss : 1.724320
# batch 177 d_loss : 0.171739
# batch 177 g_loss : 1.816792
# batch 178 d_loss : 0.181527
# batch 178 g_loss : 1.815135
# batch 179 d_loss : 0.188161
# batch 179 g_loss : 1.831905
# batch 180 d_loss : 0.187150
# batch 180 g_loss : 1.831874
# batch 181 d_loss : 0.180358
# batch 181 g_loss : 1.825673
# batch 182 d_loss : 0.190471
# batch 182 g_loss : 1.858919
# batch 183 d_loss : 0.184480
# batch 183 g_loss : 1.889917
# batch 184 d_loss : 0.201035
# batch 184 g_loss : 1.922421
# batch 185 d_loss : 0.243520
# batch 185 g_loss : 1.890016
# batch 186 d_loss : 0.220369
# batch 186 g_loss : 1.891488
# batch 187 d_loss : 0.248771
# batch 187 g_loss : 1.924255
# batch 188 d_loss : 0.224706
# batch 188 g_loss : 1.889269
# batch 189 d_loss : 0.231051
# batch 189 g_loss : 1.917498
# batch 190 d_loss : 0.249387
# batch 190 g_loss : 1.968740
# batch 191 d_loss : 0.244083
# batch 191 g_loss : 1.902623
# batch 192 d_loss : 0.232637
# batch 192 g_loss : 1.946662
# batch 193 d_loss : 0.220003
# batch 193 g_loss : 1.936891
# batch 194 d_loss : 0.237749
# batch 194 g_loss : 1.919399
# batch 195 d_loss : 0.205787
# batch 195 g_loss : 1.956747
# batch 196 d_loss : 0.227588
# batch 196 g_loss : 1.936465
# batch 197 d_loss : 0.259034
# batch 197 g_loss : 1.902709
# batch 198 d_loss : 0.265300
# batch 198 g_loss : 1.914041
# batch 199 d_loss : 0.327933
# batch 199 g_loss : 1.862607
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 200 d_loss : 0.288792
# batch 200 g_loss : 1.810320
# batch 201 d_loss : 0.254186
# batch 201 g_loss : 1.791990
# batch 202 d_loss : 0.260858
# batch 202 g_loss : 1.755362
# batch 203 d_loss : 0.254796
# batch 203 g_loss : 1.691980
# batch 204 d_loss : 0.237062
# batch 204 g_loss : 1.595922
# batch 205 d_loss : 0.224316
# batch 205 g_loss : 1.573985
# batch 206 d_loss : 0.212593
# batch 206 g_loss : 1.557437
# batch 207 d_loss : 0.228397
# batch 207 g_loss : 1.506870
# batch 208 d_loss : 0.238989
# batch 208 g_loss : 1.633392
# batch 209 d_loss : 0.233048
# batch 209 g_loss : 1.511118
# batch 210 d_loss : 0.281808
# batch 210 g_loss : 1.523927
# batch 211 d_loss : 0.266004
# batch 211 g_loss : 1.452402
# batch 212 d_loss : 0.266542
# batch 212 g_loss : 1.369633
# batch 213 d_loss : 0.272106
# batch 213 g_loss : 1.417302
# batch 214 d_loss : 0.210324
# batch 214 g_loss : 1.308592
# batch 215 d_loss : 0.263055
# batch 215 g_loss : 1.293114
# batch 216 d_loss : 0.231118
# batch 216 g_loss : 1.278297
# batch 217 d_loss : 0.266672
# batch 217 g_loss : 1.278961
# batch 218 d_loss : 0.198769
# batch 218 g_loss : 1.200767
# batch 219 d_loss : 0.199527
# batch 219 g_loss : 1.172756
# batch 220 d_loss : 0.291385
# batch 220 g_loss : 1.257481
# batch 221 d_loss : 0.328018
# batch 221 g_loss : 1.153144
# batch 222 d_loss : 0.250115
# batch 222 g_loss : 1.126725
# batch 223 d_loss : 0.216846
# batch 223 g_loss : 1.098574
# batch 224 d_loss : 0.229190
# batch 224 g_loss : 1.200351
# batch 225 d_loss : 0.243815
# batch 225 g_loss : 1.105899
# batch 226 d_loss : 0.208479
# batch 226 g_loss : 1.088241
# batch 227 d_loss : 0.216012
# batch 227 g_loss : 1.194861
# batch 228 d_loss : 0.230906
# batch 228 g_loss : 1.172986
# batch 229 d_loss : 0.249401
# batch 229 g_loss : 1.114069
# batch 230 d_loss : 0.225076
# batch 230 g_loss : 1.154347
# batch 231 d_loss : 0.265822
# batch 231 g_loss : 1.208183
# batch 232 d_loss : 0.250429
# batch 232 g_loss : 1.185299
# batch 233 d_loss : 0.297479
# batch 233 g_loss : 1.143423
# batch 234 d_loss : 0.250738
# batch 234 g_loss : 1.111645
# batch 235 d_loss : 0.302693
# batch 235 g_loss : 1.209574
# batch 236 d_loss : 0.355122
# batch 236 g_loss : 1.013293
# batch 237 d_loss : 0.351881
# batch 237 g_loss : 0.992415
# batch 238 d_loss : 0.350393
# batch 238 g_loss : 0.958653
# batch 239 d_loss : 0.334009
# batch 239 g_loss : 0.976589
# batch 240 d_loss : 0.301955
# batch 240 g_loss : 0.952794
# batch 241 d_loss : 0.327444
# batch 241 g_loss : 0.978833
# batch 242 d_loss : 0.367762
# batch 242 g_loss : 0.938334
# batch 243 d_loss : 0.424785
# batch 243 g_loss : 0.961591
# batch 244 d_loss : 0.369136
# batch 244 g_loss : 0.786608
# batch 245 d_loss : 0.440691
# batch 245 g_loss : 0.925034
# batch 246 d_loss : 0.368931
# batch 246 g_loss : 1.029336
# batch 247 d_loss : 0.371356
# batch 247 g_loss : 0.875431
# batch 248 d_loss : 0.476876
# batch 248 g_loss : 0.918717
# batch 249 d_loss : 0.589983
# batch 249 g_loss : 0.964505
# batch 250 d_loss : 0.506451
# batch 250 g_loss : 1.002291
# batch 251 d_loss : 0.478721
# batch 251 g_loss : 0.902362
# batch 252 d_loss : 0.542094
# batch 252 g_loss : 0.819409
# batch 253 d_loss : 0.444754
# batch 253 g_loss : 0.859133
# batch 254 d_loss : 0.453184
# batch 254 g_loss : 0.926968
# batch 255 d_loss : 0.526170
# batch 255 g_loss : 0.859735
# batch 256 d_loss : 0.538024
# batch 256 g_loss : 1.057279
# batch 257 d_loss : 0.566522
# batch 257 g_loss : 0.917388
# batch 258 d_loss : 0.698074
# batch 258 g_loss : 0.854821
# batch 259 d_loss : 0.665664
# batch 259 g_loss : 0.763038
# batch 260 d_loss : 0.570646
# batch 260 g_loss : 0.762981
# batch 261 d_loss : 0.562470
# batch 261 g_loss : 0.837194
# batch 262 d_loss : 0.582105
# batch 262 g_loss : 0.905006
# batch 263 d_loss : 0.622318
# batch 263 g_loss : 0.856553
# batch 264 d_loss : 0.749167
# batch 264 g_loss : 0.893421
# batch 265 d_loss : 0.743151
# batch 265 g_loss : 0.771574
# batch 266 d_loss : 0.627761
# batch 266 g_loss : 0.833242
# batch 267 d_loss : 0.519056
# batch 267 g_loss : 0.874378
# batch 268 d_loss : 0.584109
# batch 268 g_loss : 0.935627
# batch 269 d_loss : 0.594393
# batch 269 g_loss : 0.915727
# batch 270 d_loss : 0.573133
# batch 270 g_loss : 0.948869
# batch 271 d_loss : 0.572041
# batch 271 g_loss : 1.014704
# batch 272 d_loss : 0.586017
# batch 272 g_loss : 1.090035
# batch 273 d_loss : 0.663640
# batch 273 g_loss : 1.043179
# batch 274 d_loss : 0.657431
# batch 274 g_loss : 1.028606
# batch 275 d_loss : 0.649677
# batch 275 g_loss : 1.056951
# batch 276 d_loss : 0.537129
# batch 276 g_loss : 0.986248
# batch 277 d_loss : 0.668542
# batch 277 g_loss : 0.963453
# batch 278 d_loss : 0.647350
# batch 278 g_loss : 0.926178
# batch 279 d_loss : 0.485984
# batch 279 g_loss : 1.043752
# batch 280 d_loss : 0.531194
# batch 280 g_loss : 1.048235
# batch 281 d_loss : 0.487918
# batch 281 g_loss : 1.069931
# batch 282 d_loss : 0.524332
# batch 282 g_loss : 1.060727
# batch 283 d_loss : 0.499406
# batch 283 g_loss : 1.147235
# batch 284 d_loss : 0.499413
# batch 284 g_loss : 1.168911
# batch 285 d_loss : 0.508144
# batch 285 g_loss : 1.241008
# batch 286 d_loss : 0.568538
# batch 286 g_loss : 1.183643
# batch 287 d_loss : 0.482170
# batch 287 g_loss : 1.172011
# batch 288 d_loss : 0.545780
# batch 288 g_loss : 1.142097
# batch 289 d_loss : 0.534572
# batch 289 g_loss : 1.189997
# batch 290 d_loss : 0.525559
# batch 290 g_loss : 1.154779
# batch 291 d_loss : 0.535060
# batch 291 g_loss : 1.090497
# batch 292 d_loss : 0.547487
# batch 292 g_loss : 1.061724
# batch 293 d_loss : 0.471414
# batch 293 g_loss : 1.028820
# batch 294 d_loss : 0.482192
# batch 294 g_loss : 1.154531
# batch 295 d_loss : 0.529390
# batch 295 g_loss : 1.097683
# batch 296 d_loss : 0.533109
# batch 296 g_loss : 1.137199
# batch 297 d_loss : 0.513381
# batch 297 g_loss : 1.104103
# batch 298 d_loss : 0.541741
# batch 298 g_loss : 1.074206
# batch 299 d_loss : 0.558824
# batch 299 g_loss : 1.051316
# batch 300 d_loss : 0.509782
# batch 300 g_loss : 1.060855
# batch 301 d_loss : 0.558398
# batch 301 g_loss : 1.046324
# batch 302 d_loss : 0.533188
# batch 302 g_loss : 1.028618
# batch 303 d_loss : 0.512576
# batch 303 g_loss : 1.042942
# batch 304 d_loss : 0.485752
# batch 304 g_loss : 1.053735
# batch 305 d_loss : 0.500370
# batch 305 g_loss : 1.060761
# batch 306 d_loss : 0.515019
# batch 306 g_loss : 1.072896
# batch 307 d_loss : 0.530746
# batch 307 g_loss : 1.121132
# batch 308 d_loss : 0.483973
# batch 308 g_loss : 1.087032
# batch 309 d_loss : 0.479628
# batch 309 g_loss : 1.127911
# batch 310 d_loss : 0.501371
# batch 310 g_loss : 1.117367
# batch 311 d_loss : 0.561930
# batch 311 g_loss : 1.128131
# batch 312 d_loss : 0.544300
# batch 312 g_loss : 1.074780
# batch 313 d_loss : 0.501033
# batch 313 g_loss : 1.043456
# batch 314 d_loss : 0.507440
# batch 314 g_loss : 1.034943
# batch 315 d_loss : 0.489434
# batch 315 g_loss : 1.037461
# batch 316 d_loss : 0.553470
# batch 316 g_loss : 1.031333
# batch 317 d_loss : 0.567818
# batch 317 g_loss : 1.022022
# batch 318 d_loss : 0.546575
# batch 318 g_loss : 1.034552
# batch 319 d_loss : 0.520848
# batch 319 g_loss : 1.031539
# batch 320 d_loss : 0.470865
# batch 320 g_loss : 1.047819
# batch 321 d_loss : 0.502013
# batch 321 g_loss : 1.070597
# batch 322 d_loss : 0.486626
# batch 322 g_loss : 1.081948
# batch 323 d_loss : 0.525690
# batch 323 g_loss : 1.105674
# batch 324 d_loss : 0.510733
# batch 324 g_loss : 1.103306
# batch 325 d_loss : 0.558673
# batch 325 g_loss : 1.055893
# batch 326 d_loss : 0.512926
# batch 326 g_loss : 1.081349
# batch 327 d_loss : 0.519456
# batch 327 g_loss : 0.991600
# batch 328 d_loss : 0.493776
# batch 328 g_loss : 1.045008
# batch 329 d_loss : 0.486485
# batch 329 g_loss : 0.999915
# batch 330 d_loss : 0.509096
# batch 330 g_loss : 1.027704
# batch 331 d_loss : 0.485636
# batch 331 g_loss : 1.026082
# batch 332 d_loss : 0.475822
# batch 332 g_loss : 1.053378
# batch 333 d_loss : 0.531688
# batch 333 g_loss : 1.032584
# batch 334 d_loss : 0.519410
# batch 334 g_loss : 1.001792
# batch 335 d_loss : 0.516648
# batch 335 g_loss : 0.999646
# batch 336 d_loss : 0.511482
# batch 336 g_loss : 0.926700
# batch 337 d_loss : 0.473878
# batch 337 g_loss : 0.972613
# batch 338 d_loss : 0.468182
# batch 338 g_loss : 0.991629
# batch 339 d_loss : 0.486393
# batch 339 g_loss : 1.057113
# batch 340 d_loss : 0.488424
# batch 340 g_loss : 1.002793
# batch 341 d_loss : 0.511808
# batch 341 g_loss : 1.033042
# batch 342 d_loss : 0.517793
# batch 342 g_loss : 0.990409
# batch 343 d_loss : 0.462346
# batch 343 g_loss : 0.993126
# batch 344 d_loss : 0.507665
# batch 344 g_loss : 0.991199
# batch 345 d_loss : 0.468340
# batch 345 g_loss : 1.037937
# batch 346 d_loss : 0.465379
# batch 346 g_loss : 0.954892
# batch 347 d_loss : 0.514887
# batch 347 g_loss : 0.995811
# batch 348 d_loss : 0.481838
# batch 348 g_loss : 0.958470
# batch 349 d_loss : 0.453617
# batch 349 g_loss : 0.992922
# batch 350 d_loss : 0.449869
# batch 350 g_loss : 1.016297
# batch 351 d_loss : 0.478397
# batch 351 g_loss : 1.029645
# batch 352 d_loss : 0.501882
# batch 352 g_loss : 1.004344
# batch 353 d_loss : 0.476710
# batch 353 g_loss : 1.014386
# batch 354 d_loss : 0.494207
# batch 354 g_loss : 0.984220
# batch 355 d_loss : 0.491002
# batch 355 g_loss : 1.037662
# batch 356 d_loss : 0.489422
# batch 356 g_loss : 0.964191
# batch 357 d_loss : 0.505948
# batch 357 g_loss : 0.969815
# batch 358 d_loss : 0.514236
# batch 358 g_loss : 0.969186
# batch 359 d_loss : 0.555447
# batch 359 g_loss : 0.839912
# batch 360 d_loss : 0.549509
# batch 360 g_loss : 0.831366
# batch 361 d_loss : 0.516090
# batch 361 g_loss : 0.831432
# batch 362 d_loss : 0.517076
# batch 362 g_loss : 0.928202
# batch 363 d_loss : 0.501356
# batch 363 g_loss : 0.989295
# batch 364 d_loss : 0.491597
# batch 364 g_loss : 1.006722
# batch 365 d_loss : 0.487705
# batch 365 g_loss : 0.981496
# batch 366 d_loss : 0.454428
# batch 366 g_loss : 1.071894
# batch 367 d_loss : 0.433426
# batch 367 g_loss : 1.130849
# batch 368 d_loss : 0.485931
# batch 368 g_loss : 1.122732
# batch 369 d_loss : 0.491497
# batch 369 g_loss : 1.122849
# batch 370 d_loss : 0.518771
# batch 370 g_loss : 1.080238
# batch 371 d_loss : 0.505729
# batch 371 g_loss : 1.067751
# batch 372 d_loss : 0.494595
# batch 372 g_loss : 0.987771
# batch 373 d_loss : 0.520352
# batch 373 g_loss : 0.929701
# batch 374 d_loss : 0.522927
# batch 374 g_loss : 0.905273
# batch 375 d_loss : 0.586634
# batch 375 g_loss : 0.845612
# batch 376 d_loss : 0.614700
# batch 376 g_loss : 0.769744
# batch 377 d_loss : 0.538278
# batch 377 g_loss : 0.803664
# batch 378 d_loss : 0.555633
# batch 378 g_loss : 0.858094
# batch 379 d_loss : 0.562836
# batch 379 g_loss : 0.863183
# batch 380 d_loss : 0.548509
# batch 380 g_loss : 0.932145
# batch 381 d_loss : 0.476207
# batch 381 g_loss : 0.934352
# batch 382 d_loss : 0.519367
# batch 382 g_loss : 0.970634
# batch 383 d_loss : 0.588639
# batch 383 g_loss : 0.976118
# batch 384 d_loss : 0.609584
# batch 384 g_loss : 0.930016
# batch 385 d_loss : 0.572547
# batch 385 g_loss : 0.915494
# batch 386 d_loss : 0.558557
# batch 386 g_loss : 0.925732
# batch 387 d_loss : 0.532429
# batch 387 g_loss : 0.906544
# batch 388 d_loss : 0.500926
# batch 388 g_loss : 0.973234
# batch 389 d_loss : 0.533079
# batch 389 g_loss : 0.924970
# batch 390 d_loss : 0.553008
# batch 390 g_loss : 0.934927
# batch 391 d_loss : 0.511053
# batch 391 g_loss : 0.968925
# batch 392 d_loss : 0.536008
# batch 392 g_loss : 0.978002
# batch 393 d_loss : 0.543213
# batch 393 g_loss : 0.993959
# batch 394 d_loss : 0.583229
# batch 394 g_loss : 0.908345
# batch 395 d_loss : 0.563250
# batch 395 g_loss : 0.930807
# batch 396 d_loss : 0.548286
# batch 396 g_loss : 0.926867
# batch 397 d_loss : 0.566124
# batch 397 g_loss : 0.911513
# batch 398 d_loss : 0.578548
# batch 398 g_loss : 0.896624
# batch 399 d_loss : 0.526808
# batch 399 g_loss : 0.877457
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 400 d_loss : 0.539813
# batch 400 g_loss : 0.987389
# batch 401 d_loss : 0.548780
# batch 401 g_loss : 0.960765
# batch 402 d_loss : 0.519241
# batch 402 g_loss : 1.018972
# batch 403 d_loss : 0.523485
# batch 403 g_loss : 1.052246
# batch 404 d_loss : 0.558158
# batch 404 g_loss : 1.053396
# batch 405 d_loss : 0.577158
# batch 405 g_loss : 0.991336
# batch 406 d_loss : 0.539962
# batch 406 g_loss : 1.009851
# batch 407 d_loss : 0.534736
# batch 407 g_loss : 0.933450
# batch 408 d_loss : 0.553654
# batch 408 g_loss : 0.953272
# batch 409 d_loss : 0.563495
# batch 409 g_loss : 0.892419
# batch 410 d_loss : 0.543083
# batch 410 g_loss : 0.932531
# batch 411 d_loss : 0.527228
# batch 411 g_loss : 0.940427
# batch 412 d_loss : 0.555648
# batch 412 g_loss : 0.980405
# batch 413 d_loss : 0.559387
# batch 413 g_loss : 0.988146
# batch 414 d_loss : 0.583586
# batch 414 g_loss : 0.994738
# batch 415 d_loss : 0.549408
# batch 415 g_loss : 1.007219
# batch 416 d_loss : 0.526339
# batch 416 g_loss : 1.025052
# batch 417 d_loss : 0.537382
# batch 417 g_loss : 1.000755
# batch 418 d_loss : 0.572892
# batch 418 g_loss : 0.970661
# batch 419 d_loss : 0.548780
# batch 419 g_loss : 1.000116
# batch 420 d_loss : 0.517513
# batch 420 g_loss : 0.976036
# batch 421 d_loss : 0.554623
# batch 421 g_loss : 1.057181
# batch 422 d_loss : 0.513304
# batch 422 g_loss : 1.033021
# batch 423 d_loss : 0.608453
# batch 423 g_loss : 0.980959
# batch 424 d_loss : 0.606610
# batch 424 g_loss : 0.984287
# batch 425 d_loss : 0.563342
# batch 425 g_loss : 0.951048
# batch 426 d_loss : 0.602461
# batch 426 g_loss : 0.991947
# batch 427 d_loss : 0.575315
# batch 427 g_loss : 1.003250
# batch 428 d_loss : 0.502271
# batch 428 g_loss : 1.039886
# batch 429 d_loss : 0.485112
# batch 429 g_loss : 1.086962
# batch 430 d_loss : 0.482389
# batch 430 g_loss : 1.126845
# batch 431 d_loss : 0.481130
# batch 431 g_loss : 1.129982
# batch 432 d_loss : 0.490381
# batch 432 g_loss : 1.130360
# batch 433 d_loss : 0.503217
# batch 433 g_loss : 1.133522
# batch 434 d_loss : 0.493107
# batch 434 g_loss : 1.090706
# batch 435 d_loss : 0.489085
# batch 435 g_loss : 1.083196
# batch 436 d_loss : 0.538571
# batch 436 g_loss : 1.035809
# batch 437 d_loss : 0.523104
# batch 437 g_loss : 1.045161
# batch 438 d_loss : 0.528713
# batch 438 g_loss : 1.044504
# batch 439 d_loss : 0.486415
# batch 439 g_loss : 1.071751
# batch 440 d_loss : 0.520496
# batch 440 g_loss : 1.089934
# batch 441 d_loss : 0.517843
# batch 441 g_loss : 1.034383
# batch 442 d_loss : 0.513450
# batch 442 g_loss : 1.021737
# batch 443 d_loss : 0.513143
# batch 443 g_loss : 1.004292
# batch 444 d_loss : 0.537557
# batch 444 g_loss : 1.034433
# batch 445 d_loss : 0.536569
# batch 445 g_loss : 1.043880
# batch 446 d_loss : 0.488333
# batch 446 g_loss : 0.989400
# batch 447 d_loss : 0.531230
# batch 447 g_loss : 1.010615
# batch 448 d_loss : 0.550457
# batch 448 g_loss : 1.044495
# batch 449 d_loss : 0.552536
# batch 449 g_loss : 1.026652
# batch 450 d_loss : 0.531160
# batch 450 g_loss : 1.060375
# batch 451 d_loss : 0.565580
# batch 451 g_loss : 0.996234
# batch 452 d_loss : 0.576213
# batch 452 g_loss : 0.989708
# batch 453 d_loss : 0.538175
# batch 453 g_loss : 0.961190
# batch 454 d_loss : 0.515917
# batch 454 g_loss : 1.040607
# batch 455 d_loss : 0.533134
# batch 455 g_loss : 1.016175
# batch 456 d_loss : 0.538157
# batch 456 g_loss : 1.017353
# batch 457 d_loss : 0.553304
# batch 457 g_loss : 1.046499
# batch 458 d_loss : 0.502078
# batch 458 g_loss : 1.071884
# batch 459 d_loss : 0.535107
# batch 459 g_loss : 1.016598
# batch 460 d_loss : 0.547327
# batch 460 g_loss : 1.011168
# batch 461 d_loss : 0.512543
# batch 461 g_loss : 0.972683
# batch 462 d_loss : 0.496451
# batch 462 g_loss : 1.029996
# batch 463 d_loss : 0.535823
# batch 463 g_loss : 1.062234
# batch 464 d_loss : 0.553200
# batch 464 g_loss : 1.059394
# batch 465 d_loss : 0.526425
# batch 465 g_loss : 1.019600
# batch 466 d_loss : 0.549288
# batch 466 g_loss : 0.989617
# batch 467 d_loss : 0.541829
# batch 467 g_loss : 1.037579
# batch 468 d_loss : 0.536932
# batch 468 g_loss : 1.082806
# batch 469 d_loss : 0.553417
# batch 469 g_loss : 1.069083
# batch 470 d_loss : 0.561663
# batch 470 g_loss : 1.060394
# batch 471 d_loss : 0.517076
# batch 471 g_loss : 1.041334
# batch 472 d_loss : 0.552113
# batch 472 g_loss : 0.992879
# batch 473 d_loss : 0.523632
# batch 473 g_loss : 1.020688
# batch 474 d_loss : 0.530420
# batch 474 g_loss : 0.998053
# batch 475 d_loss : 0.535675
# batch 475 g_loss : 0.985640
# batch 476 d_loss : 0.600100
# batch 476 g_loss : 0.994334
# batch 477 d_loss : 0.555562
# batch 477 g_loss : 0.969959
# batch 478 d_loss : 0.519236
# batch 478 g_loss : 1.070280
# batch 479 d_loss : 0.521822
# batch 479 g_loss : 1.058054
# batch 480 d_loss : 0.514515
# batch 480 g_loss : 1.122691
# batch 481 d_loss : 0.533499
# batch 481 g_loss : 1.043408
# batch 482 d_loss : 0.560706
# batch 482 g_loss : 1.058183
# batch 483 d_loss : 0.563928
# batch 483 g_loss : 1.030335
# batch 484 d_loss : 0.546529
# batch 484 g_loss : 1.060505
# batch 485 d_loss : 0.525543
# batch 485 g_loss : 0.992164
# batch 486 d_loss : 0.537228
# batch 486 g_loss : 1.022011
# batch 487 d_loss : 0.458600
# batch 487 g_loss : 1.028969
# batch 488 d_loss : 0.532665
# batch 488 g_loss : 1.028077
# batch 489 d_loss : 0.548956
# batch 489 g_loss : 1.049271
# batch 490 d_loss : 0.552176
# batch 490 g_loss : 0.999133
# batch 491 d_loss : 0.631707
# batch 491 g_loss : 1.033087
# batch 492 d_loss : 0.533082
# batch 492 g_loss : 0.971816
# batch 493 d_loss : 0.497723
# batch 493 g_loss : 0.970756
# batch 494 d_loss : 0.527944
# batch 494 g_loss : 1.012855
# batch 495 d_loss : 0.571016
# batch 495 g_loss : 0.936366
# batch 496 d_loss : 0.508379
# batch 496 g_loss : 0.972453
# batch 497 d_loss : 0.477192
# batch 497 g_loss : 1.022376
# batch 498 d_loss : 0.574064
# batch 498 g_loss : 0.966105
# batch 499 d_loss : 0.557571
# batch 499 g_loss : 0.961306
# batch 500 d_loss : 0.522195
# batch 500 g_loss : 0.974700
# batch 501 d_loss : 0.461756
# batch 501 g_loss : 0.997297
# batch 502 d_loss : 0.506174
# batch 502 g_loss : 1.006962
# batch 503 d_loss : 0.544751
# batch 503 g_loss : 0.987067
# batch 504 d_loss : 0.534554
# batch 504 g_loss : 0.912008
# batch 505 d_loss : 0.541534
# batch 505 g_loss : 1.009693
# batch 506 d_loss : 0.560610
# batch 506 g_loss : 0.958098
# batch 507 d_loss : 0.451681
# batch 507 g_loss : 1.026730
# batch 508 d_loss : 0.468352
# batch 508 g_loss : 1.071698
# batch 509 d_loss : 0.481164
# batch 509 g_loss : 1.051094
# batch 510 d_loss : 0.447730
# batch 510 g_loss : 1.151836
# batch 511 d_loss : 0.547170
# batch 511 g_loss : 1.104329
# batch 512 d_loss : 0.551962
# batch 512 g_loss : 1.126595
# batch 513 d_loss : 0.513003
# batch 513 g_loss : 1.085864
# batch 514 d_loss : 0.503224
# batch 514 g_loss : 1.069444
# batch 515 d_loss : 0.506365
# batch 515 g_loss : 1.047755
# batch 516 d_loss : 0.499023
# batch 516 g_loss : 0.980054
# batch 517 d_loss : 0.528170
# batch 517 g_loss : 0.967381
# batch 518 d_loss : 0.496171
# batch 518 g_loss : 0.996125
# batch 519 d_loss : 0.475483
# batch 519 g_loss : 0.994144
# batch 520 d_loss : 0.556120
# batch 520 g_loss : 1.044333
# batch 521 d_loss : 0.588689
# batch 521 g_loss : 0.974599
# batch 522 d_loss : 0.484365
# batch 522 g_loss : 0.961426
# batch 523 d_loss : 0.506381
# batch 523 g_loss : 1.046286
# batch 524 d_loss : 0.457521
# batch 524 g_loss : 1.077501
# batch 525 d_loss : 0.471013
# batch 525 g_loss : 1.127861
# batch 526 d_loss : 0.521810
# batch 526 g_loss : 1.130750
# batch 527 d_loss : 0.489185
# batch 527 g_loss : 1.143096
# batch 528 d_loss : 0.471312
# batch 528 g_loss : 1.155480
# batch 529 d_loss : 0.494272
# batch 529 g_loss : 1.163589
# batch 530 d_loss : 0.475322
# batch 530 g_loss : 1.117216
# batch 531 d_loss : 0.499113
# batch 531 g_loss : 1.065909
# batch 532 d_loss : 0.457686
# batch 532 g_loss : 1.121151
# batch 533 d_loss : 0.519120
# batch 533 g_loss : 1.085394
# batch 534 d_loss : 0.478294
# batch 534 g_loss : 1.026026
# batch 535 d_loss : 0.520564
# batch 535 g_loss : 1.048620
# batch 536 d_loss : 0.482045
# batch 536 g_loss : 0.987725
# batch 537 d_loss : 0.452198
# batch 537 g_loss : 1.050227
# batch 538 d_loss : 0.455212
# batch 538 g_loss : 1.061391
# batch 539 d_loss : 0.535122
# batch 539 g_loss : 1.144427
# batch 540 d_loss : 0.519062
# batch 540 g_loss : 1.141683
# batch 541 d_loss : 0.473835
# batch 541 g_loss : 1.171489
# batch 542 d_loss : 0.479145
# batch 542 g_loss : 1.164017
# batch 543 d_loss : 0.473900
# batch 543 g_loss : 1.154573
# batch 544 d_loss : 0.491304
# batch 544 g_loss : 1.158951
# batch 545 d_loss : 0.478423
# batch 545 g_loss : 1.158577
# batch 546 d_loss : 0.470584
# batch 546 g_loss : 1.217765
# batch 547 d_loss : 0.446361
# batch 547 g_loss : 1.188630
# batch 548 d_loss : 0.523861
# batch 548 g_loss : 1.115695
# batch 549 d_loss : 0.530328
# batch 549 g_loss : 1.078298
# batch 550 d_loss : 0.512876
# batch 550 g_loss : 1.099154
# batch 551 d_loss : 0.480868
# batch 551 g_loss : 1.058633
# batch 552 d_loss : 0.482903
# batch 552 g_loss : 1.106183
# batch 553 d_loss : 0.433693
# batch 553 g_loss : 1.085354
# batch 554 d_loss : 0.426768
# batch 554 g_loss : 1.130382
# batch 555 d_loss : 0.503239
# batch 555 g_loss : 1.167332
# batch 556 d_loss : 0.503374
# batch 556 g_loss : 1.125177
# batch 557 d_loss : 0.468232
# batch 557 g_loss : 1.199444
# batch 558 d_loss : 0.443110
# batch 558 g_loss : 1.196148
# batch 559 d_loss : 0.454050
# batch 559 g_loss : 1.138704
# batch 560 d_loss : 0.487123
# batch 560 g_loss : 1.204779
# batch 561 d_loss : 0.498950
# batch 561 g_loss : 1.116228
# batch 562 d_loss : 0.493157
# batch 562 g_loss : 1.037205
# batch 563 d_loss : 0.460637
# batch 563 g_loss : 1.098950
# batch 564 d_loss : 0.491207
# batch 564 g_loss : 1.098715
# batch 565 d_loss : 0.542067
# batch 565 g_loss : 0.995195
# batch 566 d_loss : 0.540828
# batch 566 g_loss : 0.965533
# batch 567 d_loss : 0.493389
# batch 567 g_loss : 1.090733
# batch 568 d_loss : 0.490117
# batch 568 g_loss : 1.196145
# batch 569 d_loss : 0.477037
# batch 569 g_loss : 1.172434
# batch 570 d_loss : 0.499560
# batch 570 g_loss : 1.111187
# batch 571 d_loss : 0.477910
# batch 571 g_loss : 1.029289
# batch 572 d_loss : 0.489439
# batch 572 g_loss : 1.104971
# batch 573 d_loss : 0.522022
# batch 573 g_loss : 1.153980
# batch 574 d_loss : 0.484901
# batch 574 g_loss : 1.110710
# batch 575 d_loss : 0.486963
# batch 575 g_loss : 1.157703
# batch 576 d_loss : 0.474414
# batch 576 g_loss : 1.163185
# batch 577 d_loss : 0.450723
# batch 577 g_loss : 1.147645
# batch 578 d_loss : 0.461633
# batch 578 g_loss : 1.124589
# batch 579 d_loss : 0.507625
# batch 579 g_loss : 1.060764
# batch 580 d_loss : 0.466941
# batch 580 g_loss : 1.050202
# batch 581 d_loss : 0.502602
# batch 581 g_loss : 1.096850
# batch 582 d_loss : 0.469303
# batch 582 g_loss : 1.154295
# batch 583 d_loss : 0.516259
# batch 583 g_loss : 1.096905
# batch 584 d_loss : 0.475756
# batch 584 g_loss : 1.114082
# batch 585 d_loss : 0.484595
# batch 585 g_loss : 1.158369
# batch 586 d_loss : 0.385099
# batch 586 g_loss : 1.140080
# batch 587 d_loss : 0.454672
# batch 587 g_loss : 1.159157
# batch 588 d_loss : 0.454087
# batch 588 g_loss : 1.118105
# batch 589 d_loss : 0.419836
# batch 589 g_loss : 1.186919
# batch 590 d_loss : 0.431868
# batch 590 g_loss : 1.227271
# batch 591 d_loss : 0.420764
# batch 591 g_loss : 1.230667
# batch 592 d_loss : 0.428446
# batch 592 g_loss : 1.250205
# batch 593 d_loss : 0.457664
# batch 593 g_loss : 1.237000
# batch 594 d_loss : 0.503121
# batch 594 g_loss : 1.356398
# batch 595 d_loss : 0.447000
# batch 595 g_loss : 1.315988
# batch 596 d_loss : 0.486974
# batch 596 g_loss : 1.271585
# batch 597 d_loss : 0.489734
# batch 597 g_loss : 1.072518
# batch 598 d_loss : 0.445891
# batch 598 g_loss : 1.155688
# batch 599 d_loss : 0.597094
# batch 599 g_loss : 1.029948
# Epoch time calculate 837.2995466669963
# Epoch is 1
# Number of batches 600
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 0 d_loss : 0.474808
# batch 0 g_loss : 0.966448
# batch 1 d_loss : 0.469595
# batch 1 g_loss : 0.995308
# batch 2 d_loss : 0.499813
# batch 2 g_loss : 1.045759
# batch 3 d_loss : 0.431479
# batch 3 g_loss : 1.188738
# batch 4 d_loss : 0.510613
# batch 4 g_loss : 1.189960
# batch 5 d_loss : 0.513376
# batch 5 g_loss : 1.082430
# batch 6 d_loss : 0.505890
# batch 6 g_loss : 1.104964
# batch 7 d_loss : 0.483560
# batch 7 g_loss : 1.173542
# batch 8 d_loss : 0.485341
# batch 8 g_loss : 1.138703
# batch 9 d_loss : 0.500357
# batch 9 g_loss : 1.242462
# batch 10 d_loss : 0.505018
# batch 10 g_loss : 1.127756
# batch 11 d_loss : 0.531385
# batch 11 g_loss : 1.025655
# batch 12 d_loss : 0.408740
# batch 12 g_loss : 1.105615
# batch 13 d_loss : 0.438477
# batch 13 g_loss : 1.198850
# batch 14 d_loss : 0.519518
# batch 14 g_loss : 1.215638
# batch 15 d_loss : 0.504768
# batch 15 g_loss : 1.115545
# batch 16 d_loss : 0.468069
# batch 16 g_loss : 1.138257
# batch 17 d_loss : 0.428172
# batch 17 g_loss : 1.155790
# batch 18 d_loss : 0.476281
# batch 18 g_loss : 1.166083
# batch 19 d_loss : 0.439710
# batch 19 g_loss : 1.154383
# batch 20 d_loss : 0.470490
# batch 20 g_loss : 1.229487
# batch 21 d_loss : 0.425431
# batch 21 g_loss : 1.155387
# batch 22 d_loss : 0.439190
# batch 22 g_loss : 1.204717
# batch 23 d_loss : 0.492788
# batch 23 g_loss : 1.221206
# batch 24 d_loss : 0.483828
# batch 24 g_loss : 1.125922
# batch 25 d_loss : 0.445104
# batch 25 g_loss : 1.163373
# batch 26 d_loss : 0.432233
# batch 26 g_loss : 1.137292
# batch 27 d_loss : 0.524888
# batch 27 g_loss : 1.096655
# batch 28 d_loss : 0.514570
# batch 28 g_loss : 1.024265
# batch 29 d_loss : 0.429455
# batch 29 g_loss : 1.080670
# batch 30 d_loss : 0.446572
# batch 30 g_loss : 1.188993
# batch 31 d_loss : 0.439959
# batch 31 g_loss : 1.158789
# batch 32 d_loss : 0.436271
# batch 32 g_loss : 1.243982
# batch 33 d_loss : 0.462730
# batch 33 g_loss : 1.232695
# batch 34 d_loss : 0.459665
# batch 34 g_loss : 1.266201
# batch 35 d_loss : 0.523295
# batch 35 g_loss : 1.191583
# batch 36 d_loss : 0.510010
# batch 36 g_loss : 1.129943
# batch 37 d_loss : 0.483180
# batch 37 g_loss : 1.073663
# batch 38 d_loss : 0.417791
# batch 38 g_loss : 1.106763
# batch 39 d_loss : 0.410255
# batch 39 g_loss : 1.117914
# batch 40 d_loss : 0.495234
# batch 40 g_loss : 1.124242
# batch 41 d_loss : 0.505664
# batch 41 g_loss : 1.094540
# batch 42 d_loss : 0.452957
# batch 42 g_loss : 1.094482
# batch 43 d_loss : 0.443531
# batch 43 g_loss : 1.097105
# batch 44 d_loss : 0.473371
# batch 44 g_loss : 1.134987
# batch 45 d_loss : 0.478887
# batch 45 g_loss : 1.071763
# batch 46 d_loss : 0.482641
# batch 46 g_loss : 1.151340
# batch 47 d_loss : 0.540416
# batch 47 g_loss : 1.137886
# batch 48 d_loss : 0.531605
# batch 48 g_loss : 1.086650
# batch 49 d_loss : 0.426434
# batch 49 g_loss : 1.081539
# batch 50 d_loss : 0.451035
# batch 50 g_loss : 1.136684
# batch 51 d_loss : 0.451043
# batch 51 g_loss : 1.160572
# batch 52 d_loss : 0.420490
# batch 52 g_loss : 1.140065
# batch 53 d_loss : 0.466283
# batch 53 g_loss : 1.214353
# batch 54 d_loss : 0.466593
# batch 54 g_loss : 1.204654
# batch 55 d_loss : 0.426323
# batch 55 g_loss : 1.249775
# batch 56 d_loss : 0.464279
# batch 56 g_loss : 1.202049
# batch 57 d_loss : 0.430416
# batch 57 g_loss : 1.240198
# batch 58 d_loss : 0.421713
# batch 58 g_loss : 1.196040
# batch 59 d_loss : 0.469880
# batch 59 g_loss : 1.205693
# batch 60 d_loss : 0.491324
# batch 60 g_loss : 1.212865
# batch 61 d_loss : 0.460533
# batch 61 g_loss : 1.269962
# batch 62 d_loss : 0.432005
# batch 62 g_loss : 1.365972
# batch 63 d_loss : 0.424533
# batch 63 g_loss : 1.203875
# batch 64 d_loss : 0.465377
# batch 64 g_loss : 1.281454
# batch 65 d_loss : 0.424747
# batch 65 g_loss : 1.212486
# batch 66 d_loss : 0.403080
# batch 66 g_loss : 1.185618
# batch 67 d_loss : 0.454343
# batch 67 g_loss : 1.166644
# batch 68 d_loss : 0.465072
# batch 68 g_loss : 1.160687
# batch 69 d_loss : 0.469063
# batch 69 g_loss : 1.143225
# batch 70 d_loss : 0.462515
# batch 70 g_loss : 1.140519
# batch 71 d_loss : 0.438490
# batch 71 g_loss : 1.148871
# batch 72 d_loss : 0.504969
# batch 72 g_loss : 1.109553
# batch 73 d_loss : 0.502699
# batch 73 g_loss : 1.002056
# batch 74 d_loss : 0.446737
# batch 74 g_loss : 1.091999
# batch 75 d_loss : 0.446455
# batch 75 g_loss : 1.096426
# batch 76 d_loss : 0.480540
# batch 76 g_loss : 1.160194
# batch 77 d_loss : 0.469274
# batch 77 g_loss : 1.218116
# batch 78 d_loss : 0.496062
# batch 78 g_loss : 1.139345
# batch 79 d_loss : 0.512945
# batch 79 g_loss : 1.206975
# batch 80 d_loss : 0.497862
# batch 80 g_loss : 1.188865
# batch 81 d_loss : 0.422510
# batch 81 g_loss : 1.172061
# batch 82 d_loss : 0.445693
# batch 82 g_loss : 1.112255
# batch 83 d_loss : 0.498766
# batch 83 g_loss : 1.138444
# batch 84 d_loss : 0.476077
# batch 84 g_loss : 1.089844
# batch 85 d_loss : 0.469517
# batch 85 g_loss : 1.208758
# batch 86 d_loss : 0.455938
# batch 86 g_loss : 1.201816
# batch 87 d_loss : 0.452928
# batch 87 g_loss : 1.158414
# batch 88 d_loss : 0.507024
# batch 88 g_loss : 1.185799
# batch 89 d_loss : 0.421032
# batch 89 g_loss : 1.166340
# batch 90 d_loss : 0.422637
# batch 90 g_loss : 1.147856
# batch 91 d_loss : 0.429685
# batch 91 g_loss : 1.150669
# batch 92 d_loss : 0.433593
# batch 92 g_loss : 1.109484
# batch 93 d_loss : 0.480856
# batch 93 g_loss : 1.074445
# batch 94 d_loss : 0.495753
# batch 94 g_loss : 1.114890
# batch 95 d_loss : 0.444137
# batch 95 g_loss : 1.058854
# batch 96 d_loss : 0.488308
# batch 96 g_loss : 1.068087
# batch 97 d_loss : 0.447525
# batch 97 g_loss : 1.167754
# batch 98 d_loss : 0.424191
# batch 98 g_loss : 1.256034
# batch 99 d_loss : 0.421892
# batch 99 g_loss : 1.298281
# batch 100 d_loss : 0.426569
# batch 100 g_loss : 1.257401
# batch 101 d_loss : 0.435610
# batch 101 g_loss : 1.221281
# batch 102 d_loss : 0.432935
# batch 102 g_loss : 1.301575
# batch 103 d_loss : 0.419763
# batch 103 g_loss : 1.283231
# batch 104 d_loss : 0.423017
# batch 104 g_loss : 1.248387
# batch 105 d_loss : 0.467856
# batch 105 g_loss : 1.212074
# batch 106 d_loss : 0.460161
# batch 106 g_loss : 1.152133
# batch 107 d_loss : 0.432202
# batch 107 g_loss : 1.098124
# batch 108 d_loss : 0.420637
# batch 108 g_loss : 1.187243
# batch 109 d_loss : 0.448878
# batch 109 g_loss : 1.208166
# batch 110 d_loss : 0.453424
# batch 110 g_loss : 1.153408
# batch 111 d_loss : 0.395553
# batch 111 g_loss : 1.226165
# batch 112 d_loss : 0.468084
# batch 112 g_loss : 1.235052
# batch 113 d_loss : 0.422388
# batch 113 g_loss : 1.272041
# batch 114 d_loss : 0.430032
# batch 114 g_loss : 1.256777
# batch 115 d_loss : 0.446227
# batch 115 g_loss : 1.092553
# batch 116 d_loss : 0.492333
# batch 116 g_loss : 1.118136
# batch 117 d_loss : 0.433238
# batch 117 g_loss : 1.153774
# batch 118 d_loss : 0.392641
# batch 118 g_loss : 1.119055
# batch 119 d_loss : 0.425867
# batch 119 g_loss : 1.239933
# batch 120 d_loss : 0.463347
# batch 120 g_loss : 1.135671
# batch 121 d_loss : 0.449724
# batch 121 g_loss : 1.129902
# batch 122 d_loss : 0.443768
# batch 122 g_loss : 1.166214
# batch 123 d_loss : 0.521143
# batch 123 g_loss : 1.087642
# batch 124 d_loss : 0.468482
# batch 124 g_loss : 1.096950
# batch 125 d_loss : 0.420975
# batch 125 g_loss : 1.105038
# batch 126 d_loss : 0.449447
# batch 126 g_loss : 1.240957
# batch 127 d_loss : 0.445351
# batch 127 g_loss : 1.118886
# batch 128 d_loss : 0.431961
# batch 128 g_loss : 1.173150
# batch 129 d_loss : 0.517672
# batch 129 g_loss : 1.150696
# batch 130 d_loss : 0.477540
# batch 130 g_loss : 1.184339
# batch 131 d_loss : 0.475906
# batch 131 g_loss : 1.207055
# batch 132 d_loss : 0.530116
# batch 132 g_loss : 1.149811
# batch 133 d_loss : 0.471673
# batch 133 g_loss : 1.212884
# batch 134 d_loss : 0.408890
# batch 134 g_loss : 1.212990
# batch 135 d_loss : 0.431242
# batch 135 g_loss : 1.267167
# batch 136 d_loss : 0.511203
# batch 136 g_loss : 1.182331
# batch 137 d_loss : 0.457056
# batch 137 g_loss : 1.097474
# batch 138 d_loss : 0.449462
# batch 138 g_loss : 1.078285
# batch 139 d_loss : 0.521497
# batch 139 g_loss : 0.948537
# batch 140 d_loss : 0.502142
# batch 140 g_loss : 1.048565
# batch 141 d_loss : 0.541604
# batch 141 g_loss : 0.992390
# batch 142 d_loss : 0.466763
# batch 142 g_loss : 1.095333
# batch 143 d_loss : 0.520686
# batch 143 g_loss : 1.119016
# batch 144 d_loss : 0.437806
# batch 144 g_loss : 1.193161
# batch 145 d_loss : 0.475056
# batch 145 g_loss : 1.184165
# batch 146 d_loss : 0.563234
# batch 146 g_loss : 1.096749
# batch 147 d_loss : 0.587490
# batch 147 g_loss : 0.929414
# batch 148 d_loss : 0.527435
# batch 148 g_loss : 0.949774
# batch 149 d_loss : 0.422534
# batch 149 g_loss : 1.013483
# batch 150 d_loss : 0.412365
# batch 150 g_loss : 1.205395
# batch 151 d_loss : 0.449524
# batch 151 g_loss : 1.238843
# batch 152 d_loss : 0.410777
# batch 152 g_loss : 1.239812
# batch 153 d_loss : 0.395399
# batch 153 g_loss : 1.202149
# batch 154 d_loss : 0.438599
# batch 154 g_loss : 1.170089
# batch 155 d_loss : 0.462925
# batch 155 g_loss : 1.141537
# batch 156 d_loss : 0.437907
# batch 156 g_loss : 1.095495
# batch 157 d_loss : 0.467887
# batch 157 g_loss : 1.118644
# batch 158 d_loss : 0.490433
# batch 158 g_loss : 1.148020
# batch 159 d_loss : 0.504233
# batch 159 g_loss : 1.123289
# batch 160 d_loss : 0.448383
# batch 160 g_loss : 1.229668
# batch 161 d_loss : 0.434116
# batch 161 g_loss : 1.224854
# batch 162 d_loss : 0.434423
# batch 162 g_loss : 1.253810
# batch 163 d_loss : 0.414943
# batch 163 g_loss : 1.245582
# batch 164 d_loss : 0.384527
# batch 164 g_loss : 1.251275
# batch 165 d_loss : 0.394807
# batch 165 g_loss : 1.301888
# batch 166 d_loss : 0.395834
# batch 166 g_loss : 1.273150
# batch 167 d_loss : 0.441989
# batch 167 g_loss : 1.231503
# batch 168 d_loss : 0.491076
# batch 168 g_loss : 1.097190
# batch 169 d_loss : 0.473951
# batch 169 g_loss : 1.081823
# batch 170 d_loss : 0.485821
# batch 170 g_loss : 1.102254
# batch 171 d_loss : 0.484112
# batch 171 g_loss : 1.176902
# batch 172 d_loss : 0.483071
# batch 172 g_loss : 1.142405
# batch 173 d_loss : 0.441261
# batch 173 g_loss : 1.108291
# batch 174 d_loss : 0.464638
# batch 174 g_loss : 1.100563
# batch 175 d_loss : 0.491650
# batch 175 g_loss : 1.059573
# batch 176 d_loss : 0.473719
# batch 176 g_loss : 1.049984
# batch 177 d_loss : 0.455443
# batch 177 g_loss : 1.126365
# batch 178 d_loss : 0.429441
# batch 178 g_loss : 1.205959
# batch 179 d_loss : 0.419474
# batch 179 g_loss : 1.237054
# batch 180 d_loss : 0.405708
# batch 180 g_loss : 1.218597
# batch 181 d_loss : 0.373651
# batch 181 g_loss : 1.276114
# batch 182 d_loss : 0.447951
# batch 182 g_loss : 1.229856
# batch 183 d_loss : 0.413261
# batch 183 g_loss : 1.164568
# batch 184 d_loss : 0.419156
# batch 184 g_loss : 1.284176
# batch 185 d_loss : 0.449727
# batch 185 g_loss : 1.140005
# batch 186 d_loss : 0.414831
# batch 186 g_loss : 1.277138
# batch 187 d_loss : 0.402455
# batch 187 g_loss : 1.256197
# batch 188 d_loss : 0.422349
# batch 188 g_loss : 1.166725
# batch 189 d_loss : 0.416776
# batch 189 g_loss : 1.193897
# batch 190 d_loss : 0.425088
# batch 190 g_loss : 1.121563
# batch 191 d_loss : 0.400793
# batch 191 g_loss : 1.132802
# batch 192 d_loss : 0.479995
# batch 192 g_loss : 1.172538
# batch 193 d_loss : 0.503270
# batch 193 g_loss : 1.206764
# batch 194 d_loss : 0.513278
# batch 194 g_loss : 1.107762
# batch 195 d_loss : 0.474104
# batch 195 g_loss : 1.201913
# batch 196 d_loss : 0.443896
# batch 196 g_loss : 1.177525
# batch 197 d_loss : 0.406639
# batch 197 g_loss : 1.258951
# batch 198 d_loss : 0.445307
# batch 198 g_loss : 1.299682
# batch 199 d_loss : 0.535728
# batch 199 g_loss : 1.206172
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 200 d_loss : 0.498648
# batch 200 g_loss : 1.086985
# batch 201 d_loss : 0.454074
# batch 201 g_loss : 1.096657
# batch 202 d_loss : 0.468367
# batch 202 g_loss : 1.221195
# batch 203 d_loss : 0.454778
# batch 203 g_loss : 1.130650
# batch 204 d_loss : 0.407627
# batch 204 g_loss : 1.201788
# batch 205 d_loss : 0.415180
# batch 205 g_loss : 1.251016
# batch 206 d_loss : 0.418341
# batch 206 g_loss : 1.360392
# batch 207 d_loss : 0.406523
# batch 207 g_loss : 1.320969
# batch 208 d_loss : 0.498944
# batch 208 g_loss : 1.271500
# batch 209 d_loss : 0.471213
# batch 209 g_loss : 1.161557
# batch 210 d_loss : 0.395320
# batch 210 g_loss : 1.045531
# batch 211 d_loss : 0.381010
# batch 211 g_loss : 1.136666
# batch 212 d_loss : 0.386032
# batch 212 g_loss : 1.242738
# batch 213 d_loss : 0.415731
# batch 213 g_loss : 1.212910
# batch 214 d_loss : 0.394352
# batch 214 g_loss : 1.296261
# batch 215 d_loss : 0.344743
# batch 215 g_loss : 1.286978
# batch 216 d_loss : 0.372118
# batch 216 g_loss : 1.391005
# batch 217 d_loss : 0.418697
# batch 217 g_loss : 1.273921
# batch 218 d_loss : 0.409937
# batch 218 g_loss : 1.208440
# batch 219 d_loss : 0.443609
# batch 219 g_loss : 1.224716
# batch 220 d_loss : 0.451403
# batch 220 g_loss : 1.112048
# batch 221 d_loss : 0.460141
# batch 221 g_loss : 1.073763
# batch 222 d_loss : 0.405871
# batch 222 g_loss : 1.222133
# batch 223 d_loss : 0.378183
# batch 223 g_loss : 1.309069
# batch 224 d_loss : 0.424667
# batch 224 g_loss : 1.216551
# batch 225 d_loss : 0.543782
# batch 225 g_loss : 1.086421
# batch 226 d_loss : 0.525478
# batch 226 g_loss : 1.026960
# batch 227 d_loss : 0.513971
# batch 227 g_loss : 1.063886
# batch 228 d_loss : 0.494210
# batch 228 g_loss : 1.197992
# batch 229 d_loss : 0.467024
# batch 229 g_loss : 1.208419
# batch 230 d_loss : 0.496659
# batch 230 g_loss : 1.200045
# batch 231 d_loss : 0.445235
# batch 231 g_loss : 1.256701
# batch 232 d_loss : 0.443956
# batch 232 g_loss : 1.257887
# batch 233 d_loss : 0.461553
# batch 233 g_loss : 1.242501
# batch 234 d_loss : 0.416612
# batch 234 g_loss : 1.192689
# batch 235 d_loss : 0.426066
# batch 235 g_loss : 1.157599
# batch 236 d_loss : 0.410626
# batch 236 g_loss : 1.165178
# batch 237 d_loss : 0.435834
# batch 237 g_loss : 1.072011
# batch 238 d_loss : 0.448180
# batch 238 g_loss : 1.161867
# batch 239 d_loss : 0.409837
# batch 239 g_loss : 1.224095
# batch 240 d_loss : 0.405217
# batch 240 g_loss : 1.231456
# batch 241 d_loss : 0.410572
# batch 241 g_loss : 1.244875
# batch 242 d_loss : 0.489448
# batch 242 g_loss : 1.196480
# batch 243 d_loss : 0.380377
# batch 243 g_loss : 1.178660
# batch 244 d_loss : 0.413519
# batch 244 g_loss : 1.113200
# batch 245 d_loss : 0.436450
# batch 245 g_loss : 1.052229
# batch 246 d_loss : 0.445418
# batch 246 g_loss : 1.129467
# batch 247 d_loss : 0.389196
# batch 247 g_loss : 1.201013
# batch 248 d_loss : 0.399346
# batch 248 g_loss : 1.205871
# batch 249 d_loss : 0.424390
# batch 249 g_loss : 1.230389
# batch 250 d_loss : 0.405828
# batch 250 g_loss : 1.315921
# batch 251 d_loss : 0.376674
# batch 251 g_loss : 1.288451
# batch 252 d_loss : 0.387613
# batch 252 g_loss : 1.308022
# batch 253 d_loss : 0.490728
# batch 253 g_loss : 1.277838
# batch 254 d_loss : 0.484650
# batch 254 g_loss : 1.184955
# batch 255 d_loss : 0.393738
# batch 255 g_loss : 1.272148
# batch 256 d_loss : 0.398281
# batch 256 g_loss : 1.286339
# batch 257 d_loss : 0.409169
# batch 257 g_loss : 1.230687
# batch 258 d_loss : 0.373656
# batch 258 g_loss : 1.176698
# batch 259 d_loss : 0.399722
# batch 259 g_loss : 1.171532
# ...
# batch 316 d_loss : 0.172629
# batch 316 g_loss : 2.842161
# batch 317 d_loss : 0.191657
# batch 317 g_loss : 2.298543
# batch 318 d_loss : 0.228435
# batch 318 g_loss : 2.447792
# batch 319 d_loss : 0.254169
# batch 319 g_loss : 2.179711
# batch 320 d_loss : 0.242077
# batch 320 g_loss : 2.227881
# batch 321 d_loss : 0.236745
# batch 321 g_loss : 2.470760
# batch 322 d_loss : 0.161856
# batch 322 g_loss : 2.524629
# batch 323 d_loss : 0.220601
# batch 323 g_loss : 2.093306
# batch 324 d_loss : 0.242809
# batch 324 g_loss : 3.055648
# batch 325 d_loss : 0.256691
# batch 325 g_loss : 2.232963
# batch 326 d_loss : 0.213326
# batch 326 g_loss : 2.832268
# batch 327 d_loss : 0.300757
# batch 327 g_loss : 1.877602
# batch 328 d_loss : 0.323529
# batch 328 g_loss : 2.087790
# batch 329 d_loss : 0.187494
# batch 329 g_loss : 2.902840
# batch 330 d_loss : 0.243780
# batch 330 g_loss : 2.138333
# batch 331 d_loss : 0.222637
# batch 331 g_loss : 2.004061
# batch 332 d_loss : 0.210066
# batch 332 g_loss : 3.186085
# batch 333 d_loss : 0.250010
# batch 333 g_loss : 2.264832
# batch 334 d_loss : 0.220860
# batch 334 g_loss : 2.060816
# batch 335 d_loss : 0.223408
# batch 335 g_loss : 2.453439
# batch 336 d_loss : 0.262604
# batch 336 g_loss : 2.195217
# batch 337 d_loss : 0.227512
# batch 337 g_loss : 2.321100
# batch 338 d_loss : 0.228564
# batch 338 g_loss : 2.469442
# batch 339 d_loss : 0.206781
# batch 339 g_loss : 2.574729
# batch 340 d_loss : 0.182149
# batch 340 g_loss : 2.883784
# batch 341 d_loss : 0.168193
# batch 341 g_loss : 3.144563
# batch 342 d_loss : 0.207194
# batch 342 g_loss : 2.450919
# batch 343 d_loss : 0.223345
# batch 343 g_loss : 2.409213
# batch 344 d_loss : 0.202888
# batch 344 g_loss : 2.425779
# batch 345 d_loss : 0.253231
# batch 345 g_loss : 1.963414
# batch 346 d_loss : 0.241989
# batch 346 g_loss : 2.632577
# batch 347 d_loss : 0.241734
# batch 347 g_loss : 2.831359
# batch 348 d_loss : 0.188245
# batch 348 g_loss : 2.480563
# batch 349 d_loss : 0.247447
# batch 349 g_loss : 2.529624
# batch 350 d_loss : 0.235944
# batch 350 g_loss : 1.831726
# batch 351 d_loss : 0.199458
# batch 351 g_loss : 3.449432
# batch 352 d_loss : 0.207668
# batch 352 g_loss : 3.047246
# batch 353 d_loss : 0.225975
# batch 353 g_loss : 2.038353
# batch 354 d_loss : 0.248725
# batch 354 g_loss : 3.134663
# batch 355 d_loss : 0.203631
# batch 355 g_loss : 2.716912
# batch 356 d_loss : 0.255883
# batch 356 g_loss : 2.568656
# batch 357 d_loss : 0.281487
# batch 357 g_loss : 2.046967
# batch 358 d_loss : 0.257161
# batch 358 g_loss : 2.380869
# batch 359 d_loss : 0.180649
# batch 359 g_loss : 2.241311
# batch 360 d_loss : 0.170213
# batch 360 g_loss : 3.169669
# batch 361 d_loss : 0.274218
# batch 361 g_loss : 1.790699
# batch 362 d_loss : 0.278963
# batch 362 g_loss : 2.713835
# batch 363 d_loss : 0.242822
# batch 363 g_loss : 1.895968
# batch 364 d_loss : 0.227176
# batch 364 g_loss : 2.833286
# batch 365 d_loss : 0.295713
# batch 365 g_loss : 2.477518
# batch 366 d_loss : 0.224094
# batch 366 g_loss : 2.591008
# batch 367 d_loss : 0.166107
# batch 367 g_loss : 2.927656
# batch 368 d_loss : 0.184199
# batch 368 g_loss : 3.114189
# batch 369 d_loss : 0.231089
# batch 369 g_loss : 2.328732
# batch 370 d_loss : 0.227260
# batch 370 g_loss : 2.419611
# batch 371 d_loss : 0.186993
# batch 371 g_loss : 2.477471
# batch 372 d_loss : 0.158489
# batch 372 g_loss : 2.687222
# batch 373 d_loss : 0.151739
# batch 373 g_loss : 2.741006
# batch 374 d_loss : 0.166680
# batch 374 g_loss : 2.275064
# batch 375 d_loss : 0.214807
# batch 375 g_loss : 2.894424
# batch 376 d_loss : 0.267727
# batch 376 g_loss : 1.601639
# batch 377 d_loss : 0.274506
# batch 377 g_loss : 3.245327
# batch 378 d_loss : 0.239110
# batch 378 g_loss : 2.614278
# batch 379 d_loss : 0.219251
# batch 379 g_loss : 2.597769
# batch 380 d_loss : 0.221118
# batch 380 g_loss : 2.171606
# batch 381 d_loss : 0.192338
# batch 381 g_loss : 2.323225
# batch 382 d_loss : 0.222759
# batch 382 g_loss : 3.081516
# batch 383 d_loss : 0.212265
# batch 383 g_loss : 2.695482
# batch 384 d_loss : 0.293604
# batch 384 g_loss : 2.477692
# batch 385 d_loss : 0.263370
# batch 385 g_loss : 2.007600
# batch 386 d_loss : 0.208783
# batch 386 g_loss : 3.012500
# batch 387 d_loss : 0.216743
# batch 387 g_loss : 2.289985
# batch 388 d_loss : 0.256905
# batch 388 g_loss : 2.321447
# batch 389 d_loss : 0.241302
# batch 389 g_loss : 2.548233
# batch 390 d_loss : 0.260954
# batch 390 g_loss : 1.973857
# batch 391 d_loss : 0.259546
# batch 391 g_loss : 3.094529
# batch 392 d_loss : 0.217253
# batch 392 g_loss : 2.248878
# batch 393 d_loss : 0.215238
# batch 393 g_loss : 2.462228
# batch 394 d_loss : 0.211867
# batch 394 g_loss : 2.953723
# batch 395 d_loss : 0.260117
# batch 395 g_loss : 1.927329
# batch 396 d_loss : 0.242840
# batch 396 g_loss : 2.887996
# batch 397 d_loss : 0.214682
# batch 397 g_loss : 2.592061
# batch 398 d_loss : 0.217329
# batch 398 g_loss : 2.623248
# batch 399 d_loss : 0.246689
# batch 399 g_loss : 1.813210
# (100, 28, 28, 1)
# (100, 1, 28, 28)
# batch 400 d_loss : 0.252903
# batch 400 g_loss : 2.464141
# batch 401 d_loss : 0.235720
# batch 401 g_loss : 1.817378
# batch 402 d_loss : 0.241412
# batch 402 g_loss : 2.602921
# batch 403 d_loss : 0.274054
# batch 403 g_loss : 2.210071
# batch 404 d_loss : 0.170970
# batch 404 g_loss : 3.300673
# batch 405 d_loss : 0.194170
# batch 405 g_loss : 2.243067
# batch 406 d_loss : 0.216965
# batch 406 g_loss : 2.449764
# batch 407 d_loss : 0.192828
# batch 407 g_loss : 2.805961
# batch 408 d_loss : 0.258239
# batch 408 g_loss : 1.953137
# batch 409 d_loss : 0.231933
# batch 409 g_loss : 2.640407
# batch 410 d_loss : 0.205876
# batch 410 g_loss : 2.997449
# batch 411 d_loss : 0.207275
# batch 411 g_loss : 2.601018
# batch 412 d_loss : 0.209225
# batch 412 g_loss : 2.407289
# batch 413 d_loss : 0.158478
# batch 413 g_loss : 3.280476
# batch 414 d_loss : 0.162646
# batch 414 g_loss : 3.018267
# batch 415 d_loss : 0.240476
# batch 415 g_loss : 2.476809
# batch 416 d_loss : 0.181437
# batch 416 g_loss : 2.172909
# batch 417 d_loss : 0.169586
# batch 417 g_loss : 3.399060
# batch 418 d_loss : 0.244449
# batch 418 g_loss : 2.490105
# batch 419 d_loss : 0.203096
# batch 419 g_loss : 1.829696
# batch 420 d_loss : 0.297364
# batch 420 g_loss : 2.410312
# batch 421 d_loss : 0.200365
# batch 421 g_loss : 2.445698
# batch 422 d_loss : 0.182173
# batch 422 g_loss : 2.658044
# batch 423 d_loss : 0.213285
# batch 423 g_loss : 2.356931
# batch 424 d_loss : 0.267293
# batch 424 g_loss : 2.056316
# batch 425 d_loss : 0.277391
# batch 425 g_loss : 3.184651
# batch 426 d_loss : 0.294058
# batch 426 g_loss : 2.098501
# batch 427 d_loss : 0.241502
# batch 427 g_loss : 2.330358
# batch 428 d_loss : 0.236670
# batch 428 g_loss : 2.014518
# batch 429 d_loss : 0.222395
# batch 429 g_loss : 3.132401
# batch 430 d_loss : 0.266348
# batch 430 g_loss : 2.061903
# batch 431 d_loss : 0.232910
# batch 431 g_loss : 2.835778
# batch 432 d_loss : 0.203661
# batch 432 g_loss : 1.880052
# batch 433 d_loss : 0.230843
# batch 433 g_loss : 2.781382
# batch 434 d_loss : 0.237899
# batch 434 g_loss : 2.412787
# batch 435 d_loss : 0.204052
# batch 435 g_loss : 2.907879
# batch 436 d_loss : 0.218004
# batch 436 g_loss : 1.988914
# batch 437 d_loss : 0.247872
# batch 437 g_loss : 3.044354
# batch 438 d_loss : 0.175728
# batch 438 g_loss : 3.001645
# batch 439 d_loss : 0.176615
# batch 439 g_loss : 2.734338
# batch 440 d_loss : 0.155225
# batch 440 g_loss : 2.999221
# batch 441 d_loss : 0.196138
# batch 441 g_loss : 2.849703
# batch 442 d_loss : 0.200995
# batch 442 g_loss : 2.754006
# batch 443 d_loss : 0.174094
# batch 443 g_loss : 3.064037
# batch 444 d_loss : 0.188924
# batch 444 g_loss : 3.193776
# batch 445 d_loss : 0.208749
# batch 445 g_loss : 2.329413
# batch 446 d_loss : 0.235881
# batch 446 g_loss : 3.006881
# batch 447 d_loss : 0.219687
# batch 447 g_loss : 2.593074
# batch 448 d_loss : 0.202686
# batch 448 g_loss : 2.641398
# batch 449 d_loss : 0.214233
# batch 449 g_loss : 2.619613
# batch 450 d_loss : 0.250362
# batch 450 g_loss : 2.569992
# batch 451 d_loss : 0.195404
# batch 451 g_loss : 1.852057
# batch 452 d_loss : 0.235886
# batch 452 g_loss : 2.772708
# batch 453 d_loss : 0.154766
# batch 453 g_loss : 2.743001
# batch 454 d_loss : 0.166236
# batch 454 g_loss : 3.355994
# batch 455 d_loss : 0.255563
# batch 455 g_loss : 2.125635
# batch 456 d_loss : 0.334526
# batch 456 g_loss : 3.836104
# batch 457 d_loss : 0.345974
# batch 457 g_loss : 1.545678
# batch 458 d_loss : 0.260197
# batch 458 g_loss : 2.913645
# batch 459 d_loss : 0.217270
# batch 459 g_loss : 2.380803
# batch 460 d_loss : 0.154128
# batch 460 g_loss : 2.727932
# batch 461 d_loss : 0.230178
# batch 461 g_loss : 2.114730
# batch 462 d_loss : 0.197701
# batch 462 g_loss : 2.803846
# batch 463 d_loss : 0.144149
# batch 463 g_loss : 2.934612
# batch 464 d_loss : 0.250113
# batch 464 g_loss : 1.748484
# batch 465 d_loss : 0.281104
# batch 465 g_loss : 3.460667
# batch 466 d_loss : 0.218145
# batch 466 g_loss : 2.108088
# batch 467 d_loss : 0.192613
# batch 467 g_loss : 2.712266
# batch 468 d_loss : 0.204035
# batch 468 g_loss : 3.098350
# batch 469 d_loss : 0.240483
# batch 469 g_loss : 2.173958
# batch 470 d_loss : 0.189554
# batch 470 g_loss : 2.282451
# batch 471 d_loss : 0.204169
# batch 471 g_loss : 2.923728
# batch 472 d_loss : 0.280802
# batch 472 g_loss : 2.175268
# batch 473 d_loss : 0.262121
# batch 473 g_loss : 2.541133
# batch 474 d_loss : 0.236201
# batch 474 g_loss : 2.404215
# batch 475 d_loss : 0.225006
# batch 475 g_loss : 2.161510
# batch 476 d_loss : 0.263737
# batch 476 g_loss : 3.177933
# batch 477 d_loss : 0.279268
# batch 477 g_loss : 1.910317
# batch 478 d_loss : 0.187939
# batch 478 g_loss : 2.661569
# batch 479 d_loss : 0.274774
# batch 479 g_loss : 1.729962
# batch 480 d_loss : 0.272697
# batch 480 g_loss : 2.952799
# batch 481 d_loss : 0.319170
# batch 481 g_loss : 1.614638
# batch 482 d_loss : 0.322132
# batch 482 g_loss : 3.620767
# batch 483 d_loss : 0.295884
# batch 483 g_loss : 1.993547
# batch 484 d_loss : 0.228204
# batch 484 g_loss : 2.354657
# batch 485 d_loss : 0.224527
# batch 485 g_loss : 2.184778
# batch 486 d_loss : 0.245622
# batch 486 g_loss : 2.220698
# batch 487 d_loss : 0.266297
# batch 487 g_loss : 2.289591
# batch 488 d_loss : 0.227131
# batch 488 g_loss : 1.878115
# batch 489 d_loss : 0.238378
# batch 489 g_loss : 3.220286
# batch 490 d_loss : 0.183467
# batch 490 g_loss : 2.431465
# batch 491 d_loss : 0.246903
# batch 491 g_loss : 1.895686
# batch 492 d_loss : 0.237880
# batch 492 g_loss : 2.690034
# batch 493 d_loss : 0.312553
# batch 493 g_loss : 1.769883
# batch 494 d_loss : 0.204778
# batch 494 g_loss : 3.576398
# batch 495 d_loss : 0.214701
# batch 495 g_loss : 2.923624
# batch 496 d_loss : 0.218977
# batch 496 g_loss : 2.698531
# batch 497 d_loss : 0.183406
# batch 497 g_loss : 2.561669
# batch 498 d_loss : 0.247973
# batch 498 g_loss : 2.491910
# batch 499 d_loss : 0.245068
# batch 499 g_loss : 1.871460
# batch 500 d_loss : 0.241480
# batch 500 g_loss : 2.672006
# batch 501 d_loss : 0.199613
# batch 501 g_loss : 2.216428
# batch 502 d_loss : 0.233512
# batch 502 g_loss : 2.614085
# batch 503 d_loss : 0.226745
# batch 503 g_loss : 2.149068
# batch 504 d_loss : 0.230734
# batch 504 g_loss : 2.507588
# batch 505 d_loss : 0.240008
# batch 505 g_loss : 2.525930
# batch 506 d_loss : 0.225523
# batch 506 g_loss : 2.877132
# batch 507 d_loss : 0.251789
# batch 507 g_loss : 1.870492
# batch 508 d_loss : 0.322407
# batch 508 g_loss : 2.815483
# batch 509 d_loss : 0.250647
# batch 509 g_loss : 2.259278
# batch 510 d_loss : 0.250885
# batch 510 g_loss : 2.479143
# batch 511 d_loss : 0.221926
# batch 511 g_loss : 2.319423
# batch 512 d_loss : 0.211319
# batch 512 g_loss : 2.352094
# batch 513 d_loss : 0.265563
# batch 513 g_loss : 2.640589
# batch 514 d_loss : 0.223641
# batch 514 g_loss : 2.159797
# batch 515 d_loss : 0.248012
# batch 515 g_loss : 2.301168
# batch 516 d_loss : 0.172585
# batch 516 g_loss : 3.265179
# batch 517 d_loss : 0.236506
# batch 517 g_loss : 2.506295
# batch 518 d_loss : 0.227820
# batch 518 g_loss : 2.006345
# batch 519 d_loss : 0.264717
# batch 519 g_loss : 2.217051
# batch 520 d_loss : 0.303671
# batch 520 g_loss : 2.602249
# batch 521 d_loss : 0.180638
# batch 521 g_loss : 2.784046
# batch 522 d_loss : 0.212588
# batch 522 g_loss : 2.282317
# batch 523 d_loss : 0.207604
# batch 523 g_loss : 2.551596
# batch 524 d_loss : 0.223976
# batch 524 g_loss : 2.743490
# batch 525 d_loss : 0.220653
# batch 525 g_loss : 2.281121
# batch 526 d_loss : 0.230028
# batch 526 g_loss : 2.335443
# batch 527 d_loss : 0.194422
# batch 527 g_loss : 3.728261
# batch 528 d_loss : 0.320699
# batch 528 g_loss : 1.906890
# batch 529 d_loss : 0.187061
# batch 529 g_loss : 2.704710
# batch 530 d_loss : 0.249875
# batch 530 g_loss : 2.607587
# batch 531 d_loss : 0.219959
# batch 531 g_loss : 2.286535
# batch 532 d_loss : 0.199806
# batch 532 g_loss : 2.545721
# batch 533 d_loss : 0.241619
# batch 533 g_loss : 2.180698
# batch 534 d_loss : 0.227087
# batch 534 g_loss : 2.350979
# batch 535 d_loss : 0.198835
# batch 535 g_loss : 2.692575
# batch 536 d_loss : 0.162764
# batch 536 g_loss : 2.189365
# batch 537 d_loss : 0.225053
# batch 537 g_loss : 2.622734
# batch 538 d_loss : 0.220957
# batch 538 g_loss : 2.428961
# batch 539 d_loss : 0.196501
# batch 539 g_loss : 3.617279
# batch 540 d_loss : 0.195540
# batch 540 g_loss : 2.299536
# batch 541 d_loss : 0.212545
# batch 541 g_loss : 2.414289
# batch 542 d_loss : 0.167190
# batch 542 g_loss : 2.743909
# batch 543 d_loss : 0.202347
# batch 543 g_loss : 2.609084
# batch 544 d_loss : 0.242877
# batch 544 g_loss : 2.914302
# batch 545 d_loss : 0.219991
# batch 545 g_loss : 2.461736
# batch 546 d_loss : 0.206339
# batch 546 g_loss : 2.234245
# batch 547 d_loss : 0.233396
# batch 547 g_loss : 2.733427
# batch 548 d_loss : 0.224611
# batch 548 g_loss : 2.121596
# batch 549 d_loss : 0.187848
# batch 549 g_loss : 3.137400
# batch 550 d_loss : 0.224216
# batch 550 g_loss : 2.184983
# batch 551 d_loss : 0.221924
# batch 551 g_loss : 2.351252
# batch 552 d_loss : 0.268597
# batch 552 g_loss : 2.798011
# batch 553 d_loss : 0.189689
# batch 553 g_loss : 1.949118
# batch 554 d_loss : 0.221067
# batch 554 g_loss : 2.525718
# batch 555 d_loss : 0.264653
# batch 555 g_loss : 2.128722
# batch 556 d_loss : 0.284201
# batch 556 g_loss : 2.973006
# batch 557 d_loss : 0.255895
# batch 557 g_loss : 2.497112
# batch 558 d_loss : 0.171343
# batch 558 g_loss : 2.571335
# batch 559 d_loss : 0.214829
# batch 559 g_loss : 2.350461
# batch 560 d_loss : 0.168095
# batch 560 g_loss : 2.650870
# batch 561 d_loss : 0.221569
# batch 561 g_loss : 2.662548
# batch 562 d_loss : 0.217808
# batch 562 g_loss : 2.603124
# batch 563 d_loss : 0.237181
# batch 563 g_loss : 1.922909
# batch 564 d_loss : 0.208811
# batch 564 g_loss : 2.601501
# batch 565 d_loss : 0.236744
# batch 565 g_loss : 2.254802
# batch 566 d_loss : 0.291072
# batch 566 g_loss : 2.991358
# batch 567 d_loss : 0.234861
# batch 567 g_loss : 2.230903
# batch 568 d_loss : 0.194456
# batch 568 g_loss : 2.520871
# batch 569 d_loss : 0.211765
# batch 569 g_loss : 2.518292
# batch 570 d_loss : 0.362154
# batch 570 g_loss : 2.023431
# batch 571 d_loss : 0.230246
# batch 571 g_loss : 3.654097
# batch 572 d_loss : 0.210703
# batch 572 g_loss : 2.826118
# batch 573 d_loss : 0.231704
# batch 573 g_loss : 2.215835
# batch 574 d_loss : 0.209199
# batch 574 g_loss : 2.689173
# batch 575 d_loss : 0.148808
# batch 575 g_loss : 3.025558
# batch 576 d_loss : 0.168620
# batch 576 g_loss : 2.743914
# batch 577 d_loss : 0.199163
# batch 577 g_loss : 2.364621
# batch 578 d_loss : 0.181742
# batch 578 g_loss : 2.599394
# batch 579 d_loss : 0.289581
# batch 579 g_loss : 2.556422
# batch 580 d_loss : 0.206459
# batch 580 g_loss : 2.614974
# batch 581 d_loss : 0.197992
# batch 581 g_loss : 2.931805
# batch 582 d_loss : 0.200271
# batch 582 g_loss : 2.888150
# batch 583 d_loss : 0.170003
# batch 583 g_loss : 2.537623
# batch 584 d_loss : 0.246117
# batch 584 g_loss : 2.584636
# batch 585 d_loss : 0.194434
# batch 585 g_loss : 2.518768
# batch 586 d_loss : 0.245499
# batch 586 g_loss : 2.557365
# batch 587 d_loss : 0.146560
# batch 587 g_loss : 3.243733
# batch 588 d_loss : 0.246838
# batch 588 g_loss : 2.077838
# batch 589 d_loss : 0.205780
# batch 589 g_loss : 2.768278
# batch 590 d_loss : 0.191092
# batch 590 g_loss : 2.771981
# batch 591 d_loss : 0.185302
# batch 591 g_loss : 2.555116
# batch 592 d_loss : 0.138641
# batch 592 g_loss : 3.232854
# batch 593 d_loss : 0.364335
# batch 593 g_loss : 2.519180
# batch 594 d_loss : 0.302914
# batch 594 g_loss : 2.098281
# batch 595 d_loss : 0.330247
# batch 595 g_loss : 4.211481
# batch 596 d_loss : 0.270182
# batch 596 g_loss : 2.302773
# batch 597 d_loss : 0.181932
# batch 597 g_loss : 2.630070
# batch 598 d_loss : 0.255019
# batch 598 g_loss : 3.137133
# batch 599 d_loss : 0.137854
# batch 599 g_loss : 3.201392
# Epoch time calculate 850.5442655269871
